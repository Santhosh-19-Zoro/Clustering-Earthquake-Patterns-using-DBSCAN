# %%
import pandas as pd
import numpy as np
df = pd.read_parquet('earthquakes.parquet')

# %%
df.head()
# Out:
#                        time  latitude  longitude   depth  mag magType    nst  \
# 0  2025-07-31T09:10:55.974Z   52.0439   160.4564  10.000  5.3      mb  105.0
# 1  2025-07-31T08:18:36.686Z   -5.4288   146.0565  59.026  4.6      mb   33.0
# 2  2025-07-31T07:42:38.478Z   49.8822   157.4460  10.000  5.6      mb  132.0
# 3  2025-07-31T07:21:40.909Z   49.2332   157.8546  10.000  5.2      mb  113.0
# 4  2025-07-31T06:59:47.894Z   52.6423   158.8071  78.377  5.3      mb  103.0
#
#      gap   dmin   rms  ...                   updated  \
# 0   77.0  1.476  1.26  ...  2025-07-31T10:04:36.040Z
# 1  136.0  3.608  0.54  ...  2025-07-31T09:28:57.040Z
# 2   58.0  3.234  0.95  ...  2025-07-31T10:14:38.776Z
# 3   61.0  3.828  0.94  ...  2025-07-31T07:43:21.040Z
# 4  104.0  0.393  0.87  ...  2025-07-31T07:20:11.040Z
#
#                                            place        type horizontalError  \
# 0  168 km SE of Petropavlovsk-Kamchatsky, Russia  earthquake            8.19
# 1           37 km SE of Madang, Papua New Guinea  earthquake           11.03
# 2           128 km SE of Severo-Kuril’sk, Russia  earthquake            8.24
# 3           202 km SE of Severo-Kuril’sk, Russia  earthquake            6.10
# 4                42 km SE of Vilyuchinsk, Russia  earthquake            8.28
#
#   depthError  magError  magNst    status  locationSource magSource
# 0      1.810     0.027   465.0  reviewed              us        us
# 1      7.853     0.066    68.0  reviewed              us        us
# 2      1.787     0.020   862.0  reviewed              us        us
# 3      1.804     0.020   797.0  reviewed              us        us
# 4      5.212     0.020   874.0  reviewed              us        us
#
# [5 rows x 22 columns]

# %%
df1 = df.copy()

# %%
pd.set_option('display.max_columns', None)

# %%
df1.head()
# Out:
#                        time  latitude  longitude   depth  mag magType    nst  \
# 0  2025-07-31T09:10:55.974Z   52.0439   160.4564  10.000  5.3      mb  105.0
# 1  2025-07-31T08:18:36.686Z   -5.4288   146.0565  59.026  4.6      mb   33.0
# 2  2025-07-31T07:42:38.478Z   49.8822   157.4460  10.000  5.6      mb  132.0
# 3  2025-07-31T07:21:40.909Z   49.2332   157.8546  10.000  5.2      mb  113.0
# 4  2025-07-31T06:59:47.894Z   52.6423   158.8071  78.377  5.3      mb  103.0
#
#      gap   dmin   rms net          id                   updated  \
# 0   77.0  1.476  1.26  us  usd0013iej  2025-07-31T10:04:36.040Z
# 1  136.0  3.608  0.54  us  us6000qwvk  2025-07-31T09:28:57.040Z
# 2   58.0  3.234  0.95  us  us6000qwvb  2025-07-31T10:14:38.776Z
# 3   61.0  3.828  0.94  us  us6000qwv7  2025-07-31T07:43:21.040Z
# 4  104.0  0.393  0.87  us  us6000qwv0  2025-07-31T07:20:11.040Z
#
#                                            place        type  horizontalError  \
# 0  168 km SE of Petropavlovsk-Kamchatsky, Russia  earthquake             8.19
# 1           37 km SE of Madang, Papua New Guinea  earthquake            11.03
# 2           128 km SE of Severo-Kuril’sk, Russia  earthquake             8.24
# 3           202 km SE of Severo-Kuril’sk, Russia  earthquake             6.10
# 4                42 km SE of Vilyuchinsk, Russia  earthquake             8.28
#
#    depthError  magError  magNst    status locationSource magSource
# 0       1.810     0.027   465.0  reviewed             us        us
# 1       7.853     0.066    68.0  reviewed             us        us
# 2       1.787     0.020   862.0  reviewed             us        us
# 3       1.804     0.020   797.0  reviewed             us        us
# 4       5.212     0.020   874.0  reviewed             us        us

# %%
print(df1.columns)
# Out:
# Index(['time', 'latitude', 'longitude', 'depth', 'mag', 'magType', 'nst',
#        'gap', 'dmin', 'rms', 'net', 'id', 'updated', 'place', 'type',
#        'horizontalError', 'depthError', 'magError', 'magNst', 'status',
#        'locationSource', 'magSource'],
#       dtype='object')

# %%
print(df1["type"].value_counts())
# Out:
# type
# earthquake    73419
# Name: count, dtype: int64

# %%
#selecting only necessary columns
df1 = df1[['latitude', 'longitude', 'depth', 'mag']]

# %%
for i in df1.columns:
    print(f"column_name: {i}")
    print(df[i].isnull().sum())
# Out:
# column_name: latitude
# 0
# column_name: longitude
# 0
# column_name: depth
# 0
# column_name: mag
# 0

# %%
df2 = df1.copy()

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
df2[['depth','mag']] = scaler.fit_transform(df2[['depth','mag']])

# %%
print (df2.head())
# Out:
#    latitude  longitude     depth       mag
# 0   52.0439   160.4564 -0.458333  1.336499
# 1   -5.4288   146.0565 -0.029300 -0.549858
# 2   49.8822   157.4460 -0.458333  2.144938
# 3   49.2332   157.8546 -0.458333  1.067020
# 4   52.6423   158.8071  0.140043  1.336499

# %%
coords = df2[['latitude', 'longitude']].to_numpy()
coords_radians = np.radians(coords)

# %%
kms_per_radian = 6371.0088
epsilon = 50 / kms_per_radian

# %%
from sklearn.cluster import DBSCAN
db = DBSCAN(eps=epsilon, min_samples=10, metric='haversine').fit(coords_radians)

# %%
df2['cluster'] = db.labels_

# %%
df2.head()
# Out:
#    latitude  longitude     depth       mag  cluster
# 0   52.0439   160.4564 -0.458333  1.336499        0
# 1   -5.4288   146.0565 -0.029300 -0.549858        1
# 2   49.8822   157.4460 -0.458333  2.144938        0
# 3   49.2332   157.8546 -0.458333  1.067020        0
# 4   52.6423   158.8071  0.140043  1.336499        0

# %%
df1['cluster'] = df2['cluster']
df1.head()
# Out:
#    latitude  longitude   depth  mag  cluster
# 0   52.0439   160.4564  10.000  5.3        0
# 1   -5.4288   146.0565  59.026  4.6        1
# 2   49.8822   157.4460  10.000  5.6        0
# 3   49.2332   157.8546  10.000  5.2        0
# 4   52.6423   158.8071  78.377  5.3        0

# %%
print(df1['cluster'].nunique())
# Out:
# 451

# %%
df1.groupby('cluster')['cluster'].count()
# Out:
# cluster
# -1       7089
#  0       7189
#  1       3966
#  2      10170
#  3       5265
#         ...
#  445       10
#  446       13
#  447       14
#  448       15
#  449       10
# Name: cluster, Length: 451, dtype: int64

# %%
n_clusters = len(set(db.labels_)) - (1 if -1 in db.labels_ else 0) 
n_noise = list(db.labels_).count(-1)

print(n_clusters)
print(n_noise)
# Out:
# 450
# 7089

# %%
df1.to_csv('output_data.csv', index=False)
